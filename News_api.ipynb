# %%
import requests
import pandas as pd


url = "https://newsapi.org/v2/everything"


query_params = {
    'apiKey': 'e06b032123404c8b84d51bc464ef477b',
    'q': 'publishing',
    'language':'en',
    'limit':100, 
    'sortBy': 'Recent',
    'domains': 'foxnews.com,thestreet.com,NYTimes.com,forbes.com,indiewire.com,variety.com,nbcnews.com,cbsnews.com,usatoday.com,ctvnews.ca,msnbc.com,espn.com,cbcnews.ca,globalnews.ca,cnn.com,tsnnews.ca,ctvnews.ca'
}

header ={'content-type': 'application/json' }
# List variable to store individual news details
source= []
content = []
title=[]
publishedAt=[]
# dictionary variable to store all the news details
article_retrieved ={}
try:
        response = requests.get(url, params=query_params,headers=header)
        if response.status_code == 200:
                open_news_api= response.json()
                article = open_news_api["articles"]
               
                # Extract details for each article and add to the list
                
                for ar in article:
                       source.append(ar['source'])
                       content.append(ar['content'])
                       title.append(ar['title'])
                       publishedAt.append(ar['publishedAt'])
                       article_retrieved={'source':source,'content':content,'headline':title,
                                          'date_published':publishedAt}
        else:
             print('error from response')

except Exception as error:
            print(f'error:{error}')

# Create a DataFrame to print all the articles retrieved and save to CSV
try:
    if article_retrieved:
        articles_df = pd.DataFrame(article_retrieved)
        print('Articles Retrieved')
        print(articles_df)

        # Save the DataFrame to a CSV file
        output_file = 'news_articles.csv'
        articles_df.to_csv(output_file, index=False)
        print(f"Saved {len(articles_df)} articles to {output_file}")
    else:
       print("No articles retrieved.")
except Exception as e:
       print(f'error:{e}')
# Out:
# Articles Retrieved
#                                       source  \
# 0             {'id': None, 'name': 'Forbes'}
# 1             {'id': None, 'name': 'Forbes'}
# 2             {'id': None, 'name': 'Forbes'}
# 3             {'id': None, 'name': 'Forbes'}
# 4   {'id': 'usa-today', 'name': 'USA Today'}
# ..                                       ...
# 95            {'id': None, 'name': 'Forbes'}
# 96            {'id': None, 'name': 'Forbes'}
# 97            {'id': None, 'name': 'Forbes'}
# 98            {'id': None, 'name': 'Forbes'}
# 99            {'id': None, 'name': 'Forbes'}
#
#                                               content  \
# 0   Seismic change may hit publishing as Gen Zs ri...
# 1   They say all good things must come to an end. ...
# 2   Nathan Myrhvold tries to explain, in great det...
# 3   Large language models can discern stylistic pa...
# 4   Purchases you make through our links may earn ...
# ..                                                ...
# 95  Kantrell Betancourt is bullish on the use of A...
# 96  Ana Bubolea is the Founder of Buzzworthy Brand...
# 97  Silvano Marchetto, owner of Da Silvano restaur...
# 98  getty\r\nOrganic engagement and authentic cont...
# 99  TOPSHOT - Vogue Editor-in-Chief Anna Wintour p...
#
#                                              headline        date_published
# 0   Part 1: 5 Ways AI Can Transform How Publishing...  2024-06-19T14:35:22Z
# 1   Performance Publishing: Quality Media’s Strate...  2024-06-20T10:00:00Z
# 2   After Publishing Five Volumes Of Modernist Bre...  2024-07-01T13:57:27Z
# 3   Part 2: 5 Ways AI Can Transform How Publishing...  2024-07-01T14:00:53Z
# 4   When is Amazon Prime Day 2024? The best Amazon...  2024-06-25T10:35:21Z
# ..                                                ...                   ...
# 95  Kantrell Betancourt Talks New Midjourney Book,...  2024-06-14T21:59:26Z
# 96  The Ultimate ROI Of Your Brand Impact And Thou...  2024-06-20T13:45:00Z
# 97  Remembering Silvano Marchetto: He Brought Casu...  2024-06-25T14:57:03Z
# 98  16 Ways To Vet An Influencer Before Partnering...  2024-06-24T17:15:18Z
# 99  Vogue Closes Paris Fashion Week With A Grand S...  2024-06-24T11:04:20Z
#
# [100 rows x 4 columns]
# Saved 100 articles to news_articles.csv
